# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

# %%
from src.data_generator import *
from src.model import *
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
set_plot_params()

# %% [markdown]
# Generate the training data, initially consider a very simple case of constant volatility, to use as a benchmark to test the methods.

# %%
N_paths = 100000
total_timesteps = 60*60*7.5 #1 second data
n_timesteps = 60 #train at 1 minute interval

X = SemiMartingale(X_0=1.0, vol='expou', theta=2.0, beta=0.5)
x = X.generate(N_paths, total_timesteps, n_timesteps)

# %% [markdown]
# First train a model using a method of moments. We try to match the first $k$ moments of the distribution generated by
# $$
# Z_F = \frac{X_1 - X_0}{\sqrt{F(X_0,X_{1/n},X_{2/n},\ldots,X_{(n-1)/n},X_1)}}
# $$
# to those of the standard normal. We set $k=4$ and train using the $L1$ norm. We use a simple feedforward neural network, and train for 10 epochs.

# %% [markdown]
# # Model 1: using method of moments

# %%
moment_loss = MomentLoss(degree=4, p_norm=1)
moment_model = FFNetwork(n_layers=4, h_dims=128, loss=moment_loss)

# %%
history = moment_model.train(x, num_epochs=10, batch_size=256, plotting=False, lr=0.001)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Epoch 1 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 2 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 3 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 4 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 5 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 6 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 7 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 8 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 9 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 10 of 10', max=390.0, style=ProgressStyle(descripti…

# %% [markdown]
# Plot the training loss

# %%
plt.plot(history['loss'])
plt.show()

# %% [markdown]
# Test the performance of the model. First generate a new batch of data, and check the distribution of the the model, and empirical scaled return, and compare against $N(0,1)$.

# %%
x_test = X.generate(N_paths, total_timesteps, n_timesteps)
iv = moment_model.predict_iv(x_test)

# %%
plot_hist(x_test, iv, X.get_norm_increments(), n_bins=50)

# %% [markdown]
# We can see that training with just four moments is not sufficient to capture the shape of the distribution. This is reflected in the output distribution of our IV estimates (recall that in this simple example the true vol and hence IV is just constant).

# %%
plt.hist(iv, bins=50)
plt.hist(X.integrated_variance(), bins=50)
plt.show()

# %%
print(f'True IV: {X.integrated_variance().mean():.4f}')
print(f'Median estimate: {np.median(iv):.4f}, Mean estimate: {np.mean(iv):.4f}, std dev of estimates: {np.std(iv):.4f}')
# Out:
# True IV: 0.0089
# Median estimate: 0.0091, Mean estimate: 0.0092, std dev of estimates: 0.0012

# %% [markdown]
# We could train for more epochs, with a larger network or with more moments but we use an alternative method, called maximal mean discrepency. This effectively gives us a way to match the two probability distributions through a kernelised representation of the data. In particular, MMD defines a (weak) topology on probability measures, with $MMD(\mathbb{P}, \mathbb{Q}) = 0$ iff $\mathbb{P} = \mathbb{Q}$

# %% [markdown]
# # Model 2: Using (empirical) MMD

# %%
mmd_loss = MMDLoss(length_scale=1.0)
mmd_model = FFNetwork(n_layers=4, h_dims=128, loss=mmd_loss)

# %%
history = mmd_model.train(x, num_epochs=10, batch_size=256, plotting=False, lr=0.0001)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Epoch 1 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 2 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 3 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 4 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 5 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 6 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 7 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 8 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 9 of 10', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 10 of 10', max=390.0, style=ProgressStyle(descripti…

# %%
plt.plot(history['loss'])
plt.show()

# %%
iv = mmd_model.predict_iv(x_test)

# %%
plot_hist(x_test, iv, X.get_norm_increments(), n_bins=50)

# %% [markdown]
# Here we can see that the MMD model is able to reproduce the distribution completely, with the exact same architecture and training time. However, it is not in actually necessarily identifying the correct IV to do this:

# %%
plt.hist(iv, bins=50)
plt.show()

# %%
print(f'True IV: {X.integrated_variance().mean():.4f}')
print(f'Median estimate: {np.median(iv):.4f}, Mean estimate: {np.mean(iv):.4f}, std dev of estimates: {np.std(iv):.4f}')
# Out:
# True IV: 0.0060
# Median estimate: 0.0026, Mean estimate: 0.0037, std dev of estimates: 0.0088

# %% [markdown]
# We see that the model learns a distribution of IV around the correct value, but not actually the correct value uniquely. It seems highly unlikely (from experiments and further training) that this learned IV distribution would further significantly converge since the model is already able to reproduce the asymptotic ditribution to a high degree.

# %%
from scipy.stats import kstest

# %%
model_z = mmd_model.predict_z(x_test)
kstest(model_z, 'norm')
# Out:
# KstestResult(statistic=0.007047191894840779, pvalue=9.666866171271905e-05)

# %% [markdown]
# We see that from a KS test, the generated sample is indistinguishible from a standard normal. So why then are we not learning the true volatility? The reason is that all this method (not MMD specifically but targeting the asymptotic distribution) does is ensure that probability mass is distributed in the correct way, but it doesn't force pointwise convergence. So for example, consider the plot of the model $Z_F$ against the true $Z$ from the data:

# %%
sns.kdeplot(model_z, X.get_norm_increments(), cmap="Blues", shade=True, shade_lowest=True)
plt.plot((-2,2),(-2,2), color='red')
plt.xlim((-1.5,1.5))
plt.ylim((-1.5,1.5))
plt.show()

# %% [markdown]
# If the method were to uniquely recover the IV, we would expect all these points to lie on the line $y=x$, but just requiring the distributions to match is not sufficient to uniquely specify the IV - there is still some flexibility in how the mass is moved around while still acheiving the target distribution. In fact, a sufficient (but not necessary) condition to ensure the equality of the two distributions here is symmetry in line $y=x$ since that implies that mass is simply directly swapped between two regions of the support.

# %% [markdown]
# # Model 3: Using RBF MMD

# %%
rbfmmd_loss = RBFMMDLoss(length_scale=1.0)
rbfmmd_model = FFNetwork(n_layers=4, h_dims=128, loss=rbfmmd_loss)

# %%
history = rbfmmd_model.train(x, num_epochs=20, batch_size=256, plotting=False, lr=0.00001)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Epoch 1 of 20', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 2 of 20', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 3 of 20', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 4 of 20', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 5 of 20', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 6 of 20', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 7 of 20', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 8 of 20', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 9 of 20', max=390.0, style=ProgressStyle(descriptio…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 10 of 20', max=390.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 11 of 20', max=390.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 12 of 20', max=390.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 13 of 20', max=390.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 14 of 20', max=390.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 15 of 20', max=390.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 16 of 20', max=390.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 17 of 20', max=390.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 18 of 20', max=390.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 19 of 20', max=390.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Epoch 20 of 20', max=390.0, style=ProgressStyle(descripti…

# %%
iv = rbfmmd_model.predict_iv(x_test)

# %%
plot_hist(x_test, iv, X.get_norm_increments(), n_bins=50)

# %%
plt.hist(iv, bins=50)
plt.show()

# %%
model_z = rbfmmd_model.predict_z(x_test)
kstest(model_z, 'norm')
# Out:
# KstestResult(statistic=0.01418956188404441, pvalue=6.4222775017376174e-18)

# %%
plt.plot(iv[:50])
plt.plot(X.integrated_variance()[:50])

# %%
# Out:
# array([0.00794031, 0.00154377, 0.00666154, ..., 0.03099195, 0.00224252,
#        0.00122491])

# %%
sns.kdeplot(model_z, X.get_norm_increments(), cmap="Blues", shade=True, shade_lowest=True)
plt.plot((-2,2),(-2,2), color='red')
plt.xlim((-1.5,1.5))
plt.ylim((-1.5,1.5))
plt.show()

# %%
print(f'True IV: {X.integrated_variance().mean():.4f}')
print(f'Median estimate: {np.median(iv):.4f}, Mean estimate: {np.mean(iv):.4f}, std dev of estimates: {np.std(iv):.4f}')
# Out:
# True IV: 0.0089
# Median estimate: 0.0089, Mean estimate: 0.0090, std dev of estimates: 0.0012
